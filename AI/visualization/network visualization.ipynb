# %% [markdown]
# ### 1、安装Graphviz并配置用户变量path到安装路径/bin，配置系统变量path到安装路径/bin/dot.exe
# ### 2、pip install graphviz
# ### 3、pip install torchviz

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.dense = torch.nn.Linear(128, 10)

    def forward(self, x):
        x = self.dense(x)
        return x

# %%
import torch
from torchvision.models import AlexNet
from torchviz import make_dot

x=torch.rand(4,3,28,128)
#model=AlexNet()
model=Net()
print(model)
y=model(x)
# 这三种方式都可以
#g = make_dot(y)
g=make_dot(y, params=dict(model.named_parameters()))
#g = make_dot(y, params=dict(list(model.named_parameters()) + [('x', x)]))

# 这两种方法都可以
# g.view() # 会生成一个 Digraph.gv.pdf 的PDF文件
g.render('espnet_model', view=False) # 会自动保存为一个 espnet.pdf，第二个参数为True,则会自动打开该PDF文件，为False则不打开
# Out:
# Net(
#   (dense): Linear(in_features=128, out_features=10, bias=True)
# )
# 'espnet_model.pdf'

# %%
import torch
import tensorwatch as tw

from torchvision.models import resnet50
model = torch.nn.LSTM(input_size=15, hidden_size=10)
#model = resnet50()

s=tw.draw_model(model, [ 3, 512, 15])
s.save(r'alexnet.jpg')
tw.draw_model(Net(), x)

# %%
from torchvision.models import alexnet
alexnet_model =  alexnet()
tw.draw_model(alexnet_model, [1, 3, 224, 224])
img = tw.draw_model(alexnet_model, [1, 3, 224, 224])
img.save(r'D:/alexnet.jpg')
alexnet_model = torchvision.models.alexnet()
tw.model_stats(alexnet_model, [1, 3, 224, 224])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_4964/2943132548.py in <module>
#       1 from torchvision.models import alexnet
#       2 alexnet_model =  alexnet()
# ----> 3 tw.draw_model(alexnet_model, [1, 3, 224, 224])
#       4 img = tw.draw_model(alexnet_model, [1, 3, 224, 224])
#       5 img.save(r'D:/alexnet.jpg')
#
# D:\Anaconda3\lib\site-packages\tensorwatch\__init__.py in draw_model(model, input_shape, orientation, png_filename)
#      33 def draw_model(model, input_shape=None, orientation='TB', png_filename=None): #orientation = 'LR' for landscpe
#      34     from .model_graph.hiddenlayer import pytorch_draw_model
# ---> 35     g = pytorch_draw_model.draw_graph(model, input_shape)
#      36     return g
#      37
#
# ...
